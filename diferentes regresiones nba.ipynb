# %%
import pandas as pd
import numpy as np

from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# SELECCIÓN DEL MODELO Y ENTRENAMIENTO

# Lectura del dataset

dataset = pd.read_csv('C:/Users/toled/OneDrive/Documentos/MATEMÁTICAS/TFG/Dataset NBA.csv',sep=";", encoding="ISO 8859-1")
dataset = dataset.drop('YEAR', 1)
dataset = dataset.drop('Team', 1)
dataset = dataset.drop('Arena', 1)
dataset = dataset.drop('Champion', 1)
dataset = dataset.drop('Attend.', 1)
dataset = dataset.drop('L%', 1)
dataset = dataset.drop('PW', 1)
dataset = dataset.drop('PL', 1)
dataset = dataset.drop('G', 1)
dataset = dataset.drop('MP', 1)
dataset = dataset.drop('FG', 1)
dataset = dataset.drop('FGA', 1)
dataset = dataset.drop('3P', 1)
dataset = dataset.drop('3PA', 1)
dataset = dataset.drop('3P%', 1)
dataset = dataset.drop('2P', 1)
dataset = dataset.drop('2PA', 1)
dataset = dataset.drop('FT', 1)
dataset = dataset.drop('FTA', 1)
dataset = dataset.drop('FT%', 1)
dataset = dataset.drop('ORB', 1)
dataset = dataset.drop('DRB', 1)
dataset = dataset.drop('TRB', 1)
dataset = dataset.drop('AST', 1)
dataset = dataset.drop('BLK', 1)
dataset = dataset.drop('STL', 1)
dataset = dataset.drop('TOV', 1)
dataset = dataset.drop('PF', 1)
dataset = dataset.drop('Rk', 1)
dataset = dataset.drop('PTS', 1)
dataset = dataset.drop('Pace', 1)
dataset = dataset.drop('FTr', 1)
dataset = dataset.drop('3PAr', 1)

dataset.head()
# Out:
# C:\Users\toled\AppData\Local\Temp/ipykernel_15220/3651009142.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dataset = dataset.drop('YEAR', 1)
# C:\Users\toled\AppData\Local\Temp/ipykernel_15220/3651009142.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dataset = dataset.drop('Team', 1)
# C:\Users\toled\AppData\Local\Temp/ipykernel_15220/3651009142.py:8: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dataset = dataset.drop('Arena', 1)
# C:\Users\toled\AppData\Local\Temp/ipykernel_15220/3651009142.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dataset = dataset.drop('Champion', 1)
# ...

# %%
#RL four factors

X = dataset.iloc[:,9:]
y = dataset.iloc[:,3]

sc = MinMaxScaler()
sc.fit(X)
X = sc.transform(X)

# Dividir el dataset en train y test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# Create linear regression object
reg = LinearRegression()

# Train the model using the training sets
reg.fit(X_train,y_train)

# Make predictions using the testing set
y_pred = reg.predict(X_test)

# The coefficients
print("Coefficients: \n", reg.coef_)
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [ 0.68400537 -0.39786423  0.28674543  0.20125268 -0.64029308  0.36345478
#   0.24883456 -0.21075068]
# Coefficient of determination: 0.93

# %%
#RL F de Snedecor

dataset2 = dataset
dataset2 = dataset2.drop('MOV',1)
dataset2 = dataset2.drop('SOS',1)
dataset2 = dataset2.drop('OfTOV%',1)
dataset2 = dataset2.drop('DefTOV%',1)
dataset2 = dataset2.drop('ORB%',1)
dataset2 = dataset2.drop('DRB%',1)
dataset2 = dataset2.drop('Of FT/FGA',1)
dataset2 = dataset2.drop('Def FT/FGA',1)

X = dataset2.iloc[:,dataset2.columns != 'W%']
y = dataset2.iloc[:,3]

sc = MinMaxScaler()
sc.fit(X)
X = sc.transform(X)

# Dividir el dataset en train y test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# Create linear regression object
reg = LinearRegression()

# Train the model using the training sets
reg.fit(X_train,y_train)

# Make predictions using the testing set
y_pred = reg.predict(X_test)

# The coefficients
print("Coefficients: \n", reg.coef_)
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [ 0.01203898  0.00715212  0.04616214  0.77573143 -0.6774322  -0.08629365
#   0.09250604 -0.01934447]
# Coefficient of determination: 0.94
# C:\Users\toled\AppData\Local\Temp/ipykernel_15220/1687137864.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dataset2 = dataset2.drop('MOV',1)
# C:\Users\toled\AppData\Local\Temp/ipykernel_15220/1687137864.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dataset2 = dataset2.drop('SOS',1)
# C:\Users\toled\AppData\Local\Temp/ipykernel_15220/1687137864.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dataset2 = dataset2.drop('OfTOV%',1)
# ...

# %%
#RL Chi2

dataset2 = dataset
dataset2 = dataset2.drop('DEFeFG%',1)
dataset2 = dataset2.drop('FG%',1)
dataset2 = dataset2.drop('OfTOV%',1)
dataset2 = dataset2.drop('DefTOV%',1)
dataset2 = dataset2.drop('ORB%',1)
dataset2 = dataset2.drop('DRB%',1)
dataset2 = dataset2.drop('Of FT/FGA',1)
dataset2 = dataset2.drop('Def FT/FGA',1)

X = dataset2.iloc[:,dataset2.columns != 'W%']
y = dataset2.iloc[:,2]

sc = MinMaxScaler()
sc.fit(X)
X = sc.transform(X)

# Dividir el dataset en train y test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# Create linear regression object
reg = LinearRegression()

# Train the model using the training sets
reg.fit(X_train,y_train)

# Make predictions using the testing set
y_pred = reg.predict(X_test)

# The coefficients
print("Coefficients: \n", reg.coef_)
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [ 0.01238949  0.04925873  0.34469643 -0.00839325  0.4567399  -0.40840731
#   0.01094072  0.00361831]
# Coefficient of determination: 0.94
# C:\Users\toled\AppData\Local\Temp/ipykernel_15220/2016331852.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dataset2 = dataset2.drop('DEFeFG%',1)
# C:\Users\toled\AppData\Local\Temp/ipykernel_15220/2016331852.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dataset2 = dataset2.drop('FG%',1)
# C:\Users\toled\AppData\Local\Temp/ipykernel_15220/2016331852.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dataset2 = dataset2.drop('OfTOV%',1)
# ...

# %%
#RL F + Chi2

dataset2 = dataset
dataset2 = dataset2.drop('OfTOV%',1)
dataset2 = dataset2.drop('DefTOV%',1)
dataset2 = dataset2.drop('ORB%',1)
dataset2 = dataset2.drop('DRB%',1)
dataset2 = dataset2.drop('Of FT/FGA',1)
dataset2 = dataset2.drop('Def FT/FGA',1)

X = dataset2.iloc[:,dataset2.columns != 'W%']
y = dataset2.iloc[:,3]

sc = MinMaxScaler()
sc.fit(X)
X = sc.transform(X)

# Dividir el dataset en train y test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# Create linear regression object
reg = LinearRegression()

# Train the model using the training sets
reg.fit(X_train,y_train)

# Make predictions using the testing set
y_pred = reg.predict(X_test)

# The coefficients
print("Coefficients: \n", reg.coef_)
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [ 0.00775343 -0.00436062  0.04761662  0.47987548 -0.00133944  0.31889306
#  -0.28370839  0.00369002  0.03024792 -0.02460154]
# Coefficient of determination: 0.93
# C:\Users\toled\AppData\Local\Temp/ipykernel_15220/3647207734.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dataset2 = dataset2.drop('OfTOV%',1)
# C:\Users\toled\AppData\Local\Temp/ipykernel_15220/3647207734.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dataset2 = dataset2.drop('DefTOV%',1)
# C:\Users\toled\AppData\Local\Temp/ipykernel_15220/3647207734.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dataset2 = dataset2.drop('ORB%',1)
# ...

# %%
#RL F + Chi2 + four factors

dataset2 = dataset

X = dataset2.iloc[:,dataset2.columns != 'W%']
y = dataset2.iloc[:,3]

sc = MinMaxScaler()
sc.fit(X)
X = sc.transform(X)

# Dividir el dataset en train y test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# Create linear regression object
reg = LinearRegression()

# Train the model using the training sets
reg.fit(X_train,y_train)

# Make predictions using the testing set
y_pred = reg.predict(X_test)

# The coefficients
print("Coefficients: \n", reg.coef_)
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [ 0.04960382 -0.02398084  0.04307375  0.33076374  0.00249296  0.41840839
#  -0.19686163 -0.14249891  0.16618591 -0.02057237  0.01870922  0.05108409
#  -0.21230409  0.11097746  0.09305845 -0.09162462]
# Coefficient of determination: 0.94
